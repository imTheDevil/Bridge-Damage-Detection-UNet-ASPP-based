# %% [markdown]
# <a href="https://colab.research.google.com/github/imTheDevil/Bridge-Damage-Detection-UNet-ASPP-based/blob/main/Bridge%20Damage%20Detection_UNet-ASPP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import platform
print("Python version:", platform.python_version())

import sys
import os

import tensorflow as tf
print("tensorflow version:",tf.__version__)

import numpy as np
print("numpy version:",np.__version__)

import cv2
print("cv2 version:",cv2.__version__)

import matplotlib
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
print("matplotlib version:",matplotlib.__version__)

import pandas as pd
print("pandas version:",pd.__version__)

from skimage.transform import resize

from tensorflow.keras import datasets, layers, models
# Out:
# Python version: 3.7.13
# tensorflow version: 2.8.2
# numpy version: 1.21.6
# cv2 version: 4.1.2
# matplotlib version: 3.2.2
# pandas version: 1.3.5

# %%
#Importing the necessary Keras libraries for Creating the U-Net Model with gated attention and residual connections

from keras.layers import Conv2D, BatchNormalization, Activation, Add, Dropout, UpSampling2D, Input, Multiply, MaxPooling2D, Concatenate, concatenate, AveragePooling2D, Lambda, Conv2DTranspose, Reshape, ZeroPadding2D
from keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras import backend as K

# %%
path_ds = os.path.join('/content/drive/MyDrive','Tokaido Dataset') #put a path to the dataset

# %%
#Function to change the path format 
def path_correct(path):
  path = '/'.join(path[2:].split('\\'))
  path = os.path.join(path_ds, path)
  return path

# %%
#function to put the label images into 3 channels
def get_label(file_path):
  
    mask = np.squeeze(file_path, axis = 2)
    target_array = np.zeros((mask.shape[0],mask.shape[1],3))
    target_array[:,:,0]=np.where(mask == 1, 1, 0)
    target_array[:,:,1]=np.where(mask == 2, 1, 0)
    target_array[:,:,2]=np.where(mask == 3, 1, 0)
    
    return target_array

# %%
# Functions to plot the images and labels
def show_img(image):
  plt.figure()
  plt.imshow(image)
  plt.axis('off')

def show_label(label):
  fig, axes = plt.subplots(1, 3, figsize=(16, 112))
  y1 = label[:,:,0]
  y2 = label[:,:,1]
  y3 = label[:,:,2]
  plt.axis('off')
  axes[0].axis('off')
  axes[1].axis('off')
  axes[2].axis('off')
  axes[0].imshow(y1)
  axes[1].imshow(y2)
  axes[2].imshow(y3)

# %%
# Function to print the prediction images
def show_pred(y):
  fig, axes = plt.subplots(1, 3, figsize=(16, 112))
  y1 = y[:,:,0]
  y2 = y[:,:,1]
  y3 = y[:,:,2]
  plt.axis('off')
  axes[0].axis('off')
  axes[1].axis('off')
  axes[2].axis('off')
  axes[0].imshow(y1)
  axes[1].imshow(y2)
  axes[2].imshow(y3)

# %%
#function to normalize the images
def normalize(input_image):
  input_image = tf.cast(input_image, tf.float32) / 255.0
  return input_image

# %%
# Image and Label augmentation function 
def image_augmentation(img):
  seed = (2,3)
  img = tf.image.stateless_random_flip_left_right(img, seed) 
  return img

def label_augmentation(img):
  seed = (2,3)
  img = tf.image.stateless_random_flip_left_right(img, seed)
  return img

# %%
# Preprocess function to run all the required preprocessing functions on the images
def preprocess(x, y):
    def f(x, y):
        x = tf.io.read_file(x)
        y = tf.io.read_file(y)
        x = tf.io.decode_png(x, channels = 3)
        x = tf.image.resize_with_pad(x, 256, 448)
        x = tf.numpy_function(normalize, [x], [tf.float32])
        y = tf.io.decode_bmp(y, channels = 0)
        y = tf.numpy_function(get_label, [y], [tf.float32])
        y = tf.image.resize_with_pad(y, 256, 448)
        x = tf.numpy_function(image_augmentation, [x], [tf.float32])
        y = tf.numpy_function(label_augmentation, [y], [tf.float32])
        
        return x, y

    images, masks = tf.numpy_function(f, [x, y], [tf.float32, tf.float32])
    images.set_shape([256, 448, 3])
    masks.set_shape([256, 448, 3])

    return images, masks

# %%
# data pipeline function to cache dataset to ram for reducing the data loading bottleneck during training
def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.shuffle(buffer_size=1800)
    dataset = dataset.map(preprocess, num_parallel_calls= tf.data.AUTOTUNE)
    dataset = dataset.batch(batch, num_parallel_calls= tf.data.AUTOTUNE)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    dataset = dataset.cache()
    return dataset

# %%
#Loading the training data for damage images
#Access the csv file containing the absolute directory paths to each file

col_names = ['image file name', 'component label file name', 'damage label file name', 'depth image file name', 
             'camera focal length in mm', 'regular images', 'images containing damage in the RRDR']
ftrain = pd.read_csv(os.path.join(path_ds,'files_train.csv'),names = col_names,delimiter=',')
ftrain.iloc[:,0] = ftrain.iloc[:,0].apply(lambda x: path_correct(x))
ftrain.iloc[:,1] = ftrain.iloc[:,1].apply(lambda x: path_correct(x))
ftrain.iloc[:,2] = ftrain.iloc[:,2].apply(lambda x: path_correct(x))
ftrain.iloc[:,3] = ftrain.iloc[:,3].apply(lambda x: path_correct(x))
train_comp = ftrain.loc[ftrain['regular images']==True, ['image file name', 'component label file name', 'damage label file name', 'depth image file name', 'camera focal length in mm']]
train_dmg = ftrain.loc[ftrain['images containing damage in the RRDR']==True, ['image file name', 'component label file name', 'damage label file name', 'depth image file name', 'camera focal length in mm']]

# %%
train_dmg
# Out:
#                                          image file name  \
# 0      /content/drive/MyDrive/Tokaido Dataset/img_syn...
# 3      /content/drive/MyDrive/Tokaido Dataset/img_syn...
# 5      /content/drive/MyDrive/Tokaido Dataset/img_syn...
# 7      /content/drive/MyDrive/Tokaido Dataset/img_syn...
# 11     /content/drive/MyDrive/Tokaido Dataset/img_syn...
# ...                                                  ...
# 13941  /content/drive/MyDrive/Tokaido Dataset/img_syn...
# 13942  /content/drive/MyDrive/Tokaido Dataset/img_syn...
# 13945  /content/drive/MyDrive/Tokaido Dataset/img_syn...
# 13949  /content/drive/MyDrive/Tokaido Dataset/img_syn...
# 13955  /content/drive/MyDrive/Tokaido Dataset/img_syn...
#
#                                component label file name  \
# 0      /content/drive/MyDrive/Tokaido Dataset/synthet...
# 3      /content/drive/MyDrive/Tokaido Dataset/synthet...
# 5      /content/drive/MyDrive/Tokaido Dataset/synthet...
# 7      /content/drive/MyDrive/Tokaido Dataset/synthet...
# 11     /content/drive/MyDrive/Tokaido Dataset/synthet...
# ...                                                  ...
# 13941  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 13942  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 13945  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 13949  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 13955  /content/drive/MyDrive/Tokaido Dataset/synthet...
#
#                                   damage label file name  \
# 0      /content/drive/MyDrive/Tokaido Dataset/synthet...
# 3      /content/drive/MyDrive/Tokaido Dataset/synthet...
# 5      /content/drive/MyDrive/Tokaido Dataset/synthet...
# 7      /content/drive/MyDrive/Tokaido Dataset/synthet...
# 11     /content/drive/MyDrive/Tokaido Dataset/synthet...
# ...                                                  ...
# 13941  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 13942  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 13945  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 13949  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 13955  /content/drive/MyDrive/Tokaido Dataset/synthet...
#
#                                    depth image file name  \
# 0      /content/drive/MyDrive/Tokaido Dataset/synthet...
# 3      /content/drive/MyDrive/Tokaido Dataset/synthet...
# 5      /content/drive/MyDrive/Tokaido Dataset/synthet...
# 7      /content/drive/MyDrive/Tokaido Dataset/synthet...
# 11     /content/drive/MyDrive/Tokaido Dataset/synthet...
# ...                                                  ...
# 13941  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 13942  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 13945  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 13949  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 13955  /content/drive/MyDrive/Tokaido Dataset/synthet...
#
#        camera focal length in mm
# 0                      43.375470
# 3                      43.242723
# 5                      20.921244
# 7                      46.639972
# 11                     53.623157
# ...                          ...
# 13941                  51.725212
# 13942                  53.422408
# 13945                  41.561651
# 13949                  36.669088
# 13955                  54.680956
#
# [4381 rows x 5 columns]

# %%
#Printing the training image

#image
print(ftrain.iloc[3])
image = mpimg.imread(ftrain.iloc[3][0])
print(image.shape)
print(type(image))
plt.imshow(image)
# Out:
# image file name                         /content/drive/MyDrive/Tokaido Dataset/img_syn...
# component label file name               /content/drive/MyDrive/Tokaido Dataset/synthet...
# damage label file name                  /content/drive/MyDrive/Tokaido Dataset/synthet...
# depth image file name                   /content/drive/MyDrive/Tokaido Dataset/synthet...
# camera focal length in mm                                                       43.242723
# regular images                                                                       True
# images containing damage in the RRDR                                                 True
# Name: 3, dtype: object
# (1080, 1920, 3)
# <class 'numpy.ndarray'>

# %%
#label
#Printing the above image label
print(ftrain.iloc[3])
image = mpimg.imread(ftrain.iloc[3][2])#[x][y] x = row no. & y = {0:raw image, 1:component label, 2:damage label, 3:depth label}
print(image.shape)
print(type(image))
plt.imshow(image)
# Out:
# image file name                         /content/drive/MyDrive/Tokaido Dataset/img_syn...
# component label file name               /content/drive/MyDrive/Tokaido Dataset/synthet...
# damage label file name                  /content/drive/MyDrive/Tokaido Dataset/synthet...
# depth image file name                   /content/drive/MyDrive/Tokaido Dataset/synthet...
# camera focal length in mm                                                       43.242723
# regular images                                                                       True
# images containing damage in the RRDR                                                 True
# Name: 3, dtype: object
# (360, 640)
# <class 'numpy.ndarray'>

# %%
#Loading the training data from the pure_tex file

#Access the csv file containing the absolute directory paths to each file

col_names = ['image file name', 'damage label file name']

ftrain_tex = pd.read_csv(os.path.join(path_ds,'files_puretex_train.csv'),names = col_names,delimiter=',')
ftrain_tex.iloc[:,0] = ftrain_tex.iloc[:,0].apply(lambda x: path_correct(x))
ftrain_tex.iloc[:,1] = ftrain_tex.iloc[:,1].apply(lambda x: path_correct(x))

train_dmg_tex = ftrain_tex

# %%
train_dmg_tex
# Out:
#                                         image file name  \
# 0     /content/drive/MyDrive/Tokaido Dataset/images_...
# 1     /content/drive/MyDrive/Tokaido Dataset/images_...
# 2     /content/drive/MyDrive/Tokaido Dataset/images_...
# 3     /content/drive/MyDrive/Tokaido Dataset/images_...
# 4     /content/drive/MyDrive/Tokaido Dataset/images_...
# ...                                                 ...
# 2695  /content/drive/MyDrive/Tokaido Dataset/images_...
# 2696  /content/drive/MyDrive/Tokaido Dataset/images_...
# 2697  /content/drive/MyDrive/Tokaido Dataset/images_...
# 2698  /content/drive/MyDrive/Tokaido Dataset/images_...
# 2699  /content/drive/MyDrive/Tokaido Dataset/images_...
#
#                                  damage label file name
# 0     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 1     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 2     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 3     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 4     /content/drive/MyDrive/Tokaido Dataset/synthet...
# ...                                                 ...
# 2695  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 2696  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 2697  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 2698  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 2699  /content/drive/MyDrive/Tokaido Dataset/synthet...
#
# [2700 rows x 2 columns]

# %%
#Printing the training image
print(ftrain_tex.iloc[2])
image = mpimg.imread(ftrain_tex.iloc[2][1])
print(image.shape)
print(type(image))
plt.imshow(image)
# Out:
# image file name           /content/drive/MyDrive/Tokaido Dataset/images_...
# damage label file name    /content/drive/MyDrive/Tokaido Dataset/synthet...
# Name: 2, dtype: object
# (360, 640)
# <class 'numpy.ndarray'>

# %%
#splitting the data for training and validation and also joining the dataset of both texture and component demage

#Run for training on the damage images

train1 = train_dmg[:4000]
val1 = train_dmg[4000:]

#appending texture images to the training and validation dataset
train1 = train1.append(train_dmg_tex[:2300])
val1 = val1.append(train_dmg_tex[2300:])

# %%
train1
# Out:
#                                         image file name  \
# 0     /content/drive/MyDrive/Tokaido Dataset/img_syn...
# 3     /content/drive/MyDrive/Tokaido Dataset/img_syn...
# 5     /content/drive/MyDrive/Tokaido Dataset/img_syn...
# 7     /content/drive/MyDrive/Tokaido Dataset/img_syn...
# 11    /content/drive/MyDrive/Tokaido Dataset/img_syn...
# ...                                                 ...
# 2295  /content/drive/MyDrive/Tokaido Dataset/images_...
# 2296  /content/drive/MyDrive/Tokaido Dataset/images_...
# 2297  /content/drive/MyDrive/Tokaido Dataset/images_...
# 2298  /content/drive/MyDrive/Tokaido Dataset/images_...
# 2299  /content/drive/MyDrive/Tokaido Dataset/images_...
#
#                               component label file name  \
# 0     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 3     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 5     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 7     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 11    /content/drive/MyDrive/Tokaido Dataset/synthet...
# ...                                                 ...
# 2295                                                NaN
# 2296                                                NaN
# 2297                                                NaN
# 2298                                                NaN
# 2299                                                NaN
#
#                                  damage label file name  \
# 0     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 3     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 5     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 7     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 11    /content/drive/MyDrive/Tokaido Dataset/synthet...
# ...                                                 ...
# 2295  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 2296  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 2297  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 2298  /content/drive/MyDrive/Tokaido Dataset/synthet...
# 2299  /content/drive/MyDrive/Tokaido Dataset/synthet...
#
#                                   depth image file name  \
# 0     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 3     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 5     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 7     /content/drive/MyDrive/Tokaido Dataset/synthet...
# 11    /content/drive/MyDrive/Tokaido Dataset/synthet...
# ...                                                 ...
# 2295                                                NaN
# 2296                                                NaN
# 2297                                                NaN
# 2298                                                NaN
# 2299                                                NaN
#
#       camera focal length in mm
# 0                     43.375470
# 3                     43.242723
# 5                     20.921244
# 7                     46.639972
# 11                    53.623157
# ...                         ...
# 2295                        NaN
# 2296                        NaN
# 2297                        NaN
# 2298                        NaN
# 2299                        NaN
#
# [6300 rows x 5 columns]

# %%
# Creating the tf dataset from dataframe containing image addresses

images = train1['image file name'].to_numpy()
masks = train1['damage label file name'].to_numpy()
dataset = tf_dataset(images, masks)
images_val = val1['image file name'].to_numpy()
masks_val = val1['damage label file name'].to_numpy()
dataset_val = tf_dataset(images_val, masks_val)

# %%
#Printing out an image for reference
for x, y in dataset.take(2):
        show_img(x[0])
        show_label(y[0])
        
        break

# %%
#number of features to be used in the model df for encoder and uf for decoder, 32 was found to be optimal for both
df=32
uf=32
    
def build_unet(input_shape):

  #convolution block with batch normalization to be used in both encoder and decoder

  def conv2d(layer_input,filters,dropout_rate=0):
    d = Conv2D(filters,kernel_size=(3,3),strides=(1,1),padding='same')(layer_input)
    d = BatchNormalization()(d)
    d = Activation('relu')(d)
      
    d = Conv2D(filters,kernel_size=(3,3),strides=(1,1),padding='same')(d)
    d = BatchNormalization()(d)
    d = Activation('relu')(d)

    d = Conv2D(filters,kernel_size=(3,3),strides=(1,1),padding='same')(d)
    d = BatchNormalization()(d)

    sc = Conv2D(filters,kernel_size=(1,1),padding='same')(layer_input)
    sc = BatchNormalization()(sc)

    rp = Add()([sc,d])
    rp = Activation('relu')(rp)
    rp = Dropout(dropout_rate)(rp)
      
    return rp

  #convolution block without batch normalization to be used in both encoder and decoder

  def conv2d_wobn(layer_input,filters,dropout_rate=0):
    d = Conv2D(filters,kernel_size=(3,3),strides=(1,1),padding='same')(layer_input)
    d = Activation('relu')(d)
      
    d = Conv2D(filters,kernel_size=(3,3),strides=(1,1),padding='same')(d)
    d = Activation('relu')(d)

    d = Conv2D(filters,kernel_size=(3,3),strides=(1,1),padding='same')(d)

    sc = Conv2D(filters,kernel_size=(1,1),padding='same')(layer_input)

    rp = Add()([sc,d])
    rp = Activation('relu')(rp)
    rp = Dropout(dropout_rate)(rp)

    return rp
    
  #upsampling and convolution block with batch normalization to be used in decoder

  def deconv2d(layer_input,filters):
    u = UpSampling2D((2,2))(layer_input)
    u = Conv2D(filters,kernel_size=(3,3),strides=(1,1),padding='same')(u)
    u = BatchNormalization()(u)
    u = Activation('relu')(u)

    u = Conv2D(filters,kernel_size=(3,3),strides=(1,1),padding='same')(u)
    u = BatchNormalization()(u)
    u = Activation('relu')(u)
      
    return u

  #attention block with batch normalization to be used in place of skip connections for gated attention

  def attention_block(F_g,F_l,F_int):
    g = Conv2D(F_int,kernel_size=(1,1),strides=(1,1),padding='valid')(F_g)
    g = BatchNormalization()(g)
    x = Conv2D(F_int,kernel_size=(1,1),strides=(1,1),padding='valid')(F_l)
    x = BatchNormalization()(x)
    psi = Add()([g,x])
    psi = Activation('relu')(psi)
    
    psi = Conv2D(1,kernel_size=(1,1),strides=(1,1),padding='valid')(psi)
      
    psi = BatchNormalization()(psi)
    psi = Activation('sigmoid')(psi)
      
    return Multiply()([F_l,psi])


  #"Source: https://github.com/srihari-humbarwadi/DeepLabV3_Plus-Tensorflow2.0/blob/master/deeplab.py"
  #ASPP


  def Upsample(tensor, size):
    '''bilinear upsampling'''
    name = tensor.name.split('/')[0] + '_upsample'

    def bilinear_upsample(x, size):
        resized = tf.image.resize(
            images=x, size=size)
        return resized
    y = Lambda(lambda x: bilinear_upsample(x, size),
               output_shape=size, name=name)(tensor)
    return y
  
  def ASPP(tensor):
    '''atrous spatial pyramid pooling'''
    dims = K.int_shape(tensor)

    y_pool = AveragePooling2D(pool_size=(
        dims[1], dims[2]), name='average_pooling')(tensor)
    y_pool = Conv2D(filters=256, kernel_size=1, padding='same',
                    kernel_initializer='he_normal', name='pool_1x1conv2d', use_bias=False)(y_pool)
    y_pool = BatchNormalization(name=f'bn_1')(y_pool)
    y_pool = Activation('relu', name=f'relu_1')(y_pool)

    y_pool = Upsample(tensor=y_pool, size=[dims[1], dims[2]])

    y_1 = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same',
                 kernel_initializer='he_normal', name='ASPP_conv2d_d1', use_bias=False)(tensor)
    y_1 = BatchNormalization(name=f'bn_2')(y_1)
    y_1 = Activation('relu', name=f'relu_2')(y_1)

    y_6 = Conv2D(filters=256, kernel_size=3, dilation_rate=6, padding='same',
                 kernel_initializer='he_normal', name='ASPP_conv2d_d6', use_bias=False)(tensor)
    y_6 = BatchNormalization(name=f'bn_3')(y_6)
    y_6 = Activation('relu', name=f'relu_3')(y_6)

    y_12 = Conv2D(filters=256, kernel_size=3, dilation_rate=12, padding='same',
                  kernel_initializer='he_normal', name='ASPP_conv2d_d12', use_bias=False)(tensor)
    y_12 = BatchNormalization(name=f'bn_4')(y_12)
    y_12 = Activation('relu', name=f'relu_4')(y_12)

    y_18 = Conv2D(filters=256, kernel_size=3, dilation_rate=18, padding='same',
                  kernel_initializer='he_normal', name='ASPP_conv2d_d18', use_bias=False)(tensor)
    y_18 = BatchNormalization(name=f'bn_5')(y_18)
    y_18 = Activation('relu', name=f'relu_5')(y_18)

    y = concatenate([y_pool, y_1, y_6, y_12, y_18], name='ASPP_concat')

    y = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same',
               kernel_initializer='he_normal', name='ASPP_conv2d_final', use_bias=False)(y)
    y = BatchNormalization(name=f'bn_final')(y)
    y = Activation('relu', name=f'relu_final')(y)
    return y




  #actual model definition depth = 4, i.e. 4 times downsampled by fator of 2 (by maxpooling)

  inputs = Input(input_shape)
    
  conv1 = conv2d_wobn(inputs,df)
  pool1 = MaxPooling2D((2,2))(conv1)
    
  conv2 = conv2d(pool1,df*2)
  pool2 = MaxPooling2D((2,2))(conv2)
    
  conv3 = conv2d(pool2,df*4)
  pool3 = MaxPooling2D((2,2))(conv3)
    
  #conv4 = conv2d(pool3,df*8)
  #pool4 = MaxPooling2D((2,2))(conv4)
  
  pool4 = ASPP(pool3)
  conv6 = conv2d(pool4,df*4)
    
  #up6 = deconv2d(conv5,uf*8)
  #conv6 = attention_block(up6,conv4,uf*8)
  #up6 = Concatenate()([up6,conv6])
  #conv6 = conv2d_wobn(up6,uf*8)
  
  up7 = deconv2d(conv6,uf*4)
  conv7 = attention_block(up7,conv3,uf*4)
  up7 = Concatenate()([up7,conv7])
  conv7 = conv2d_wobn(up7,uf*4)
    
  up8 = deconv2d(conv7,uf*2)
  conv8 = attention_block(up8,conv2,uf*2)
  up8 = Concatenate()([up8,conv8])
  conv8 = conv2d_wobn(up8,uf*2)
    
  up9 = deconv2d(conv8,uf)
  conv9 = attention_block(up9,conv1,uf)
  up9 = Concatenate()([up9,conv9])
  conv9 = conv2d_wobn(up9,uf)

  #here the first input to Conv2D i.e. 3 defines the output number of classes to be pridicted

  outputs = Conv2D(3,kernel_size=(1,1),strides=(1,1),activation='sigmoid')(conv9)
   
  model = Model(inputs=inputs,outputs=outputs)
    
  return model

# %%
#building the unet model with gated attention and residual connections and printing its summary
model = build_unet((256,448,3))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 448, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 448, 32  896         ['input_1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 256, 448, 32  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 448, 32  9248        ['activation[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 256, 448, 32  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 448, 32  128         ['input_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 448, 32  9248        ['activation_1[0][0]']
#                                 )
#
#  add (Add)                      (None, 256, 448, 32  0           ['conv2d_3[0][0]',
#                                 )                                 'conv2d_2[0][0]']
#
#  activation_2 (Activation)      (None, 256, 448, 32  0           ['add[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 256, 448, 32  0           ['activation_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 224, 32  0           ['dropout[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 224, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 224, 64  256        ['conv2d_4[0][0]']
#  alization)                     )
#
#  activation_3 (Activation)      (None, 128, 224, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 224, 64  36928       ['activation_3[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 224, 64  256        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 128, 224, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 128, 224, 64  2112        ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 128, 224, 64  36928       ['activation_4[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 224, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  batch_normalization_2 (BatchNo  (None, 128, 224, 64  256        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  add_1 (Add)                    (None, 128, 224, 64  0           ['batch_normalization_3[0][0]',
#                                 )                                 'batch_normalization_2[0][0]']
#
#  activation_5 (Activation)      (None, 128, 224, 64  0           ['add_1[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 128, 224, 64  0           ['activation_5[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 112, 64)  0          ['dropout_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 112, 128  73856       ['max_pooling2d_1[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 64, 112, 128  512        ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 64, 112, 128  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 64, 112, 128  147584      ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 64, 112, 128  512        ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 64, 112, 128  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 64, 112, 128  8320        ['max_pooling2d_1[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 64, 112, 128  147584      ['activation_7[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 64, 112, 128  512        ['conv2d_11[0][0]']
#  rmalization)                   )
#
#  batch_normalization_6 (BatchNo  (None, 64, 112, 128  512        ['conv2d_10[0][0]']
#  rmalization)                   )
#
#  add_2 (Add)                    (None, 64, 112, 128  0           ['batch_normalization_7[0][0]',
#                                 )                                 'batch_normalization_6[0][0]']
#
#  activation_8 (Activation)      (None, 64, 112, 128  0           ['add_2[0][0]']
#                                 )
#
#  dropout_2 (Dropout)            (None, 64, 112, 128  0           ['activation_8[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 56, 128)  0          ['dropout_2[0][0]']
#
#  average_pooling (AveragePoolin  (None, 1, 1, 128)   0           ['max_pooling2d_2[0][0]']
#  g2D)
#
#  pool_1x1conv2d (Conv2D)        (None, 1, 1, 256)    32768       ['average_pooling[0][0]']
#
#  bn_1 (BatchNormalization)      (None, 1, 1, 256)    1024        ['pool_1x1conv2d[0][0]']
#
#  ASPP_conv2d_d1 (Conv2D)        (None, 32, 56, 256)  32768       ['max_pooling2d_2[0][0]']
#
#  ASPP_conv2d_d6 (Conv2D)        (None, 32, 56, 256)  294912      ['max_pooling2d_2[0][0]']
#
#  ASPP_conv2d_d12 (Conv2D)       (None, 32, 56, 256)  294912      ['max_pooling2d_2[0][0]']
#
#  ASPP_conv2d_d18 (Conv2D)       (None, 32, 56, 256)  294912      ['max_pooling2d_2[0][0]']
#
#  relu_1 (Activation)            (None, 1, 1, 256)    0           ['bn_1[0][0]']
#
#  bn_2 (BatchNormalization)      (None, 32, 56, 256)  1024        ['ASPP_conv2d_d1[0][0]']
#
#  bn_3 (BatchNormalization)      (None, 32, 56, 256)  1024        ['ASPP_conv2d_d6[0][0]']
#
#  bn_4 (BatchNormalization)      (None, 32, 56, 256)  1024        ['ASPP_conv2d_d12[0][0]']
#
#  bn_5 (BatchNormalization)      (None, 32, 56, 256)  1024        ['ASPP_conv2d_d18[0][0]']
#
#  relu_1_upsample (Lambda)       (None, 32, 56, 256)  0           ['relu_1[0][0]']
#
#  relu_2 (Activation)            (None, 32, 56, 256)  0           ['bn_2[0][0]']
#
#  relu_3 (Activation)            (None, 32, 56, 256)  0           ['bn_3[0][0]']
#
#  relu_4 (Activation)            (None, 32, 56, 256)  0           ['bn_4[0][0]']
#
#  relu_5 (Activation)            (None, 32, 56, 256)  0           ['bn_5[0][0]']
#
#  ASPP_concat (Concatenate)      (None, 32, 56, 1280  0           ['relu_1_upsample[0][0]',
#                                 )                                 'relu_2[0][0]',
#                                                                   'relu_3[0][0]',
#                                                                   'relu_4[0][0]',
#                                                                   'relu_5[0][0]']
#
#  ASPP_conv2d_final (Conv2D)     (None, 32, 56, 256)  327680      ['ASPP_concat[0][0]']
#
#  bn_final (BatchNormalization)  (None, 32, 56, 256)  1024        ['ASPP_conv2d_final[0][0]']
#
#  relu_final (Activation)        (None, 32, 56, 256)  0           ['bn_final[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 56, 128)  295040      ['relu_final[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 56, 128)  512        ['conv2d_12[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 56, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 56, 128)  147584      ['activation_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 56, 128)  512        ['conv2d_13[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 32, 56, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 56, 128)  32896       ['relu_final[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 56, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 56, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_10 (BatchN  (None, 32, 56, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 32, 56, 128)  0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 32, 56, 128)  0           ['add_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 32, 56, 128)  0           ['activation_11[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 112, 128  0           ['dropout_3[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 64, 112, 128  147584      ['up_sampling2d[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 64, 112, 128  512        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 64, 112, 128  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 64, 112, 128  147584      ['activation_12[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 64, 112, 128  512        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_13 (Activation)     (None, 64, 112, 128  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 64, 112, 128  16512       ['activation_13[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 64, 112, 128  16512       ['dropout_2[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 64, 112, 128  512        ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  batch_normalization_15 (BatchN  (None, 64, 112, 128  512        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  add_4 (Add)                    (None, 64, 112, 128  0           ['batch_normalization_14[0][0]',
#                                 )                                 'batch_normalization_15[0][0]']
#
#  activation_14 (Activation)     (None, 64, 112, 128  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 64, 112, 1)   129         ['activation_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 64, 112, 1)  4           ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 112, 1)   0           ['batch_normalization_16[0][0]']
#
#  multiply (Multiply)            (None, 64, 112, 128  0           ['dropout_2[0][0]',
#                                 )                                 'activation_15[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 112, 256  0           ['activation_13[0][0]',
#                                 )                                 'multiply[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 112, 128  295040      ['concatenate[0][0]']
#                                 )
#
#  activation_16 (Activation)     (None, 64, 112, 128  0           ['conv2d_21[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 64, 112, 128  147584      ['activation_16[0][0]']
#                                 )
#
#  activation_17 (Activation)     (None, 64, 112, 128  0           ['conv2d_22[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 64, 112, 128  32896       ['concatenate[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 64, 112, 128  147584      ['activation_17[0][0]']
#                                 )
#
#  add_5 (Add)                    (None, 64, 112, 128  0           ['conv2d_24[0][0]',
#                                 )                                 'conv2d_23[0][0]']
#
#  activation_18 (Activation)     (None, 64, 112, 128  0           ['add_5[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 64, 112, 128  0           ['activation_18[0][0]']
#                                 )
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 224, 12  0          ['dropout_4[0][0]']
#                                 8)
#
#  conv2d_25 (Conv2D)             (None, 128, 224, 64  73792       ['up_sampling2d_1[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 128, 224, 64  256        ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 128, 224, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 128, 224, 64  36928       ['activation_19[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 128, 224, 64  256        ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  activation_20 (Activation)     (None, 128, 224, 64  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 128, 224, 64  4160        ['activation_20[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 128, 224, 64  4160        ['dropout_1[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 128, 224, 64  256        ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  batch_normalization_20 (BatchN  (None, 128, 224, 64  256        ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  add_6 (Add)                    (None, 128, 224, 64  0           ['batch_normalization_19[0][0]',
#                                 )                                 'batch_normalization_20[0][0]']
#
#  activation_21 (Activation)     (None, 128, 224, 64  0           ['add_6[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 128, 224, 1)  65          ['activation_21[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 128, 224, 1)  4          ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 128, 224, 1)  0           ['batch_normalization_21[0][0]']
#
#  multiply_1 (Multiply)          (None, 128, 224, 64  0           ['dropout_1[0][0]',
#                                 )                                 'activation_22[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 128, 224, 12  0           ['activation_20[0][0]',
#                                 8)                                'multiply_1[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 128, 224, 64  73792       ['concatenate_1[0][0]']
#                                 )
#
#  activation_23 (Activation)     (None, 128, 224, 64  0           ['conv2d_30[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 128, 224, 64  36928       ['activation_23[0][0]']
#                                 )
#
#  activation_24 (Activation)     (None, 128, 224, 64  0           ['conv2d_31[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 128, 224, 64  8256        ['concatenate_1[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 128, 224, 64  36928       ['activation_24[0][0]']
#                                 )
#
#  add_7 (Add)                    (None, 128, 224, 64  0           ['conv2d_33[0][0]',
#                                 )                                 'conv2d_32[0][0]']
#
#  activation_25 (Activation)     (None, 128, 224, 64  0           ['add_7[0][0]']
#                                 )
#
#  dropout_5 (Dropout)            (None, 128, 224, 64  0           ['activation_25[0][0]']
#                                 )
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 448, 64  0          ['dropout_5[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 256, 448, 32  18464       ['up_sampling2d_2[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 256, 448, 32  128        ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  activation_26 (Activation)     (None, 256, 448, 32  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 256, 448, 32  9248        ['activation_26[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 256, 448, 32  128        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_27 (Activation)     (None, 256, 448, 32  0           ['batch_normalization_23[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 256, 448, 32  1056        ['activation_27[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 256, 448, 32  1056        ['dropout[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 256, 448, 32  128        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  batch_normalization_25 (BatchN  (None, 256, 448, 32  128        ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  add_8 (Add)                    (None, 256, 448, 32  0           ['batch_normalization_24[0][0]',
#                                 )                                 'batch_normalization_25[0][0]']
#
#  activation_28 (Activation)     (None, 256, 448, 32  0           ['add_8[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 256, 448, 1)  33          ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 256, 448, 1)  4          ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 256, 448, 1)  0           ['batch_normalization_26[0][0]']
#
#  multiply_2 (Multiply)          (None, 256, 448, 32  0           ['dropout[0][0]',
#                                 )                                 'activation_29[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 256, 448, 64  0           ['activation_27[0][0]',
#                                 )                                 'multiply_2[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 256, 448, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  activation_30 (Activation)     (None, 256, 448, 32  0           ['conv2d_39[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 256, 448, 32  9248        ['activation_30[0][0]']
#                                 )
#
#  activation_31 (Activation)     (None, 256, 448, 32  0           ['conv2d_40[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 256, 448, 32  2080        ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 256, 448, 32  9248        ['activation_31[0][0]']
#                                 )
#
#  add_9 (Add)                    (None, 256, 448, 32  0           ['conv2d_42[0][0]',
#                                 )                                 'conv2d_41[0][0]']
#
#  activation_32 (Activation)     (None, 256, 448, 32  0           ['add_9[0][0]']
#                                 )
#
#  dropout_6 (Dropout)            (None, 256, 448, 32  0           ['activation_32[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 256, 448, 3)  99          ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 3,702,674
# Trainable params: 3,695,244
# Non-trainable params: 7,430
# __________________________________________________________________________________________________

# %%
#using Adam optimizer and fixing the learning rate 
optimizer_adam = tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

# %%
#Checkpoint for model saving and reloading the saved weights
# "training_dmg_resatt_final/cp_dmg.ckpt" this checkpoint to be supplied for best weights as trained by us
checkpoint_path = os.path.join(path_ds, "training_dmg_resatt_final/cp_dmg.ckpt")
checkpoint_dir = os.path.dirname(checkpoint_path)


cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,  monitor = 'iou', mode='max', save_best_only = True,
                                                 verbose=1)

# %%
""" Courtesy stackoverflow Daniel Möller https://stackoverflow.com/users/2097240/daniel-m%c3%b6ller?tab=profile
answer to question 'Custom loss function for U-net in keras using class weights: `class_weight` not supported for 3+ dimensional targets' 
"""
# Weighted loss function 
def weightedLoss(originalLossFunc, weightsList):

    def lossFunc(true, pred):

        axis = -1 #if channels last 
        #axis=  1 #if channels first


        #argmax returns the index of the element with the greatest value
        #done in the class axis, it returns the class index    
        classSelectors = K.argmax(true, axis=axis)
        classSelectors = tf.cast(classSelectors, tf.int32) 
            #if your loss is sparse, use only true as classSelectors

        #considering weights are ordered by class, for each class
        #true(1) if the class index is equal to the weight index   
        classSelectors = [K.equal(i, classSelectors) for i in range(len(weightsList))]

        #casting boolean to float for calculations  
        #each tensor in the list contains 1 where ground true class is equal to its index 
        #if you sum all these, you will get a tensor full of ones. 
        classSelectors = [K.cast(x, K.floatx()) for x in classSelectors]

        #for each of the selections above, multiply their respective weight
        weights = [sel * w for sel,w in zip(classSelectors, weightsList)] 

        #sums all the selections
        #result is a tensor with the respective weight for each element in predictions
        weightMultiplier = weights[0]
        for i in range(1, len(weights)):
            weightMultiplier = weightMultiplier + weights[i]


        #make sure your originalLossFunc only collapses the class axis
        #you need the other axes intact to multiply the weights tensor
        loss = originalLossFunc(true,pred) 
        loss = loss * weightMultiplier

        return loss
    return lossFunc

# %%
#summation of dice loss and cross entropy loss

from keras import backend as K
def DiceCELoss(targets, inputs, smooth=1e-6):
    CE = tf.keras.metrics.binary_crossentropy(targets, inputs)
    y_true_f=K.flatten(targets)
    y_pred_f=K.flatten(inputs)
    intersection=K.sum(y_true_f*y_pred_f)
    dice_loss=1-((2*intersection) + smooth)/(K.sum(y_true_f*y_true_f)+K.sum(y_pred_f*y_pred_f)+ smooth)
    dice_CE=dice_loss+CE
    return dice_CE

# %%
#summation of log of (1-dice loss) and cross entropy loss

import math
from keras import backend as K
def logDiceCELoss(targets, inputs, smooth=1e-6):
    CE = tf.keras.metrics.binary_crossentropy(targets, inputs)
    #CE = tf.keras.metrics.CategoricalCrossentropy(targets, inputs)
    y_true_f=K.flatten(targets)
    y_pred_f=K.flatten(inputs)
    intersection=K.sum(y_true_f*y_pred_f)
    dice_loss=1-((2*intersection) + smooth)/(K.sum(y_true_f*y_true_f)+K.sum(y_pred_f*y_pred_f)+ smooth)
    dice_CE=CE-math.log(1-dice_loss)
    return dice_CE

# %%
# The weights for each class are hardcoded here and are calculated using the code presented towards the end of this notebook
w1= 0.03611688490088685
w2= 1.0
w3=9.345573778790564

# %%
#best results were obtained with binary cross entropy loss

model.compile(optimizer= optimizer_adam,
              loss= weightedLoss(tf.keras.losses.BinaryCrossentropy(), [w1,w2,w3]),
              metrics=[
                       tf.keras.metrics.BinaryAccuracy(),
                       tf.keras.metrics.Recall(thresholds = 0.2),
                       tf.keras.metrics.Precision(thresholds = 0.7),
                       tf.keras.metrics.MeanIoU(3,name="iou")])

# %%
#run this cell for loading the weights from saved checkpoints
model.load_weights(checkpoint_path)

# %% [markdown]
# #**Training, Metrics and Validation**

# %%
#Train the model
history = model.fit(dataset, epochs= 30 ,validation_data= dataset_val, verbose = 1, callbacks=[cp_callback])

# %%
#Print Loss
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure()
plt.plot(history.epoch, loss, 'r', label='Training loss')
plt.plot(history.epoch, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-5a3821b32b6e> in <module>()
#       1 #Print Loss
# ----> 2 loss = history.history['loss']
#       3 val_loss = history.history['val_loss']
#       4
#       5 plt.figure()
#
# TypeError: 'History' object is not subscriptable

# %%
#Print Binary Accuracy
accu = history.history['binary_accuracy']
val_accu = history.history['val_binary_accuracy']

plt.figure()
plt.plot(history.epoch, accu, 'r', label='Training binary accuracy')
plt.plot(history.epoch, val_accu, 'b', label='Validation binary accuracy')
plt.title('Training and Validation binary accuracy')
plt.xlabel('Epoch')
plt.ylabel('binary accuracy Value')
plt.legend()
plt.show()

# %%
#print recall
recall = history.history['recall']
val_recall = history.history['val_recall']

plt.figure()
plt.plot(history.epoch, recall, 'r', label='Training recall')
plt.plot(history.epoch, val_recall, 'b', label='Validation recall')
plt.title('Training and Validation recall')
plt.xlabel('Epoch')
plt.ylabel('recall Value')
plt.legend()
plt.show()

# %%
#Print precision
pres = history.history['precision']
val_pres = history.history['val_precision']

plt.figure()
plt.plot(history.epoch, pres, 'r', label='Training precision')
plt.plot(history.epoch, val_pres, 'b', label='Validation precision')
plt.title('Training and Validation precision')
plt.xlabel('Epoch')
plt.ylabel('precision Value')
plt.legend()
plt.show()

# %%
#Print Mean IoU
miou = history.history['iou']
val_miou = history.history['val_iou']

plt.figure()
plt.plot(history.epoch, miou, 'r', label='Training mean_io_u')
plt.plot(history.epoch, val_miou, 'b', label='Validation mean_io_u')
plt.title('Training and Validation mean_io_u')
plt.xlabel('Epoch')
plt.ylabel('mean_io_u Value')
plt.legend()
plt.show()

# %%
#Evaluate the model on validation dataset
model.evaluate(dataset_val, verbose = 1)
# Out:
# 98/98 [==============================] - 10s 104ms/step - loss: 0.0088 - binary_accuracy: 0.9766 - recall: 0.9785 - precision: 0.9850 - iou: 0.3505
# [0.008757410570979118,
#  0.9765729308128357,
#  0.97853022813797,
#  0.9849870800971985,
#  0.35050201416015625]

# %%
#Printing predictions on the validation dataset
z=1
for x, y in dataset_val.take(10):
        z += 1
        show_img(x[2])
        show_label(y[2])
        pred = model.predict(x)
        show_pred(pred[2])
        if (z==9):
          break
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [markdown]
# #**Testing**

# %%
#Preprocessing for the test dataset
def preprocess_test(x,y):
    def f(x,y):
        x = tf.io.read_file(x)
        y = tf.io.read_file(y)
        x = tf.io.decode_png(x, channels = 3)
        x = tf.image.resize_with_pad(x, 256,448)
        x = tf.numpy_function(normalize, [x], [tf.float32]) 
        y = tf.io.decode_png(y, channels = 0)   
        y = tf.numpy_function(get_label_tex, [y], [tf.float32])
        y = tf.image.resize_with_pad(y, 256, 448)   

        return x, y

    images, masks = tf.numpy_function(f, [x, y], [tf.float32, tf.float32])
    images.set_shape([256, 448, 3])
    masks.set_shape([256, 448, 3])

    return images, masks

# %%
#dataloader for the test dataset
def tf_dataset_test(x,y, batch = 8):
    dataset = tf.data.Dataset.from_tensor_slices((x,y))
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    dataset = dataset.map(preprocess_test, num_parallel_calls= tf.data.AUTOTUNE)
    dataset = dataset.batch(batch, num_parallel_calls= tf.data.AUTOTUNE)
    dataset = dataset.cache()
    return dataset

# %%
#Function to change the path format 
def path_correct_png(path):
  path = '/'.join(path[2:].split('\\'))
  path = os.path.join(path_ds, path)
  path = path[:-4] + '.png'
  return path

# %%
#Loading the training data from the pure_tex file

#Access the csv file containing the absolute directory paths to each file

col_names = ['image file name', 'damage label file name']

ftest = pd.read_csv(os.path.join(path_ds,'files_puretex_test.csv'),names = col_names,delimiter=',')
ftest.iloc[:,0] = ftest.iloc[:,0].apply(lambda x: path_correct(x))
ftest.iloc[:,1] = ftest.iloc[:,1].apply(lambda x: path_correct_png(x))

test_dmg_tex = ftest

# %%
# creating dataloader for texture images
images_test = test_dmg_tex['image file name'].to_numpy()
masks_test = test_dmg_tex['damage label file name'].to_numpy()
dataset_test_tex = tf_dataset_test(images_test,masks_test)
address_tex = test_dmg_tex['damage label file name'].apply(lambda x : os.path.split(x)[1]).to_numpy()

# %%
#Printing predictions on the texture test dataset
z=1
for x, y in dataset_test_tex.take(10):
        z += 1
        show_img(x[2])
        show_label(y[2])
        pred = model.predict(x)
        show_pred(pred[2])
        if (z==9):
          break
# Out:
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-47-06efd15dd190> in <module>()
#       1 #Printing predictions on the texture test dataset
#       2 z=1
# ----> 3 for x, y in dataset_test_tex.take(10):
#       4         z += 1
#       5         show_img(x[2])
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __next__(self)
#     834   def __next__(self):
#     835     try:
# --> 836       return self._next_internal()
#     837     except errors.OutOfRangeError:
#     838       raise StopIteration
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _next_internal(self)
#     820           self._iterator_resource,
#     821           output_types=self._flat_output_types,
# --> 822           output_shapes=self._flat_output_shapes)
#     823
#     824       try:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    2921       return _result
#    2922     except _core._NotOkStatusException as e:
# -> 2923       _ops.raise_from_not_ok_status(e, name)
#    2924     except _core._FallbackException:
#    2925       pass
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    7184 def raise_from_not_ok_status(e, name):
#    7185   e.message += (" name: " + name if name is not None else "")
# -> 7186   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    7187
#    7188
#
# UnknownError: NotFoundError: /content/drive/MyDrive/Tokaido Dataset/synthetic_puretex/labdmg/im311_ConcreteDamaged.png; No such file or directory [Op:ReadFile]
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/script_ops.py", line 271, in __call__
#     ret = func(*args)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py", line 642, in wrapper
#     return func(*args, **kwargs)
#
#   File "/tmp/__autograph_generated_file0kc0u2wa.py", line 17, in f
#     y = ag__.converted_call(ag__.ld(tf).io.read_file, (ag__.ld(y),), None, fscope_1)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py", line 335, in converted_call
#     return _call_unconverted(f, args, kwargs, options, False)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py", line 459, in _call_unconverted
#     return f(*args)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/io_ops.py", line 133, in read_file
#     return gen_io_ops.read_file(filename, name)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_io_ops.py", line 567, in read_file
#     filename, name=name, ctx=_ctx)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_io_ops.py", line 590, in read_file_eager_fallback
#     attrs=_attrs, ctx=ctx, name=name)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py", line 55, in quick_execute
#     inputs, attrs, num_outputs)
#
# tensorflow.python.framework.errors_impl.NotFoundError: /content/drive/MyDrive/Tokaido Dataset/synthetic_puretex/labdmg/im311_ConcreteDamaged.png; No such file or directory [Op:ReadFile]
#
#
# 	 [[{{node PyFunc}}]] [Op:IteratorGetNext]

# %%
# Loading the testing data from the component demage test dataset file

#Access the csv file containing the absolute directory paths to each file

col_names = ['image file name', 'component label file name', 'damage label file name', 'depth image file name', 
             'camera focal length in mm', 'regular images', 'images containing damage in the RRDR']
ftest = pd.read_csv(os.path.join(path_ds,'files_test.csv'),names = col_names,delimiter=',')
ftest.iloc[:,0] = ftest.iloc[:,0].apply(lambda x: path_correct(x))
ftest.iloc[:,1] = ftest.iloc[:,1].apply(lambda x: path_correct(x))
ftest.iloc[:,2] = ftest.iloc[:,2].apply(lambda x: path_correct_png(x))
ftest.iloc[:,3] = ftest.iloc[:,3].apply(lambda x: path_correct(x))
test_comp = ftest.loc[ftest['images containing damage in the RRDR']==True, ['image file name', 'component label file name', 'damage label file name', 'depth image file name', 'camera focal length in mm']]

# %%
# creating dataloader for component damage images

images_test = test_comp['image file name'].to_numpy()
masks_test = test_comp['damage label file name'].to_numpy()
dataset_test = tf_dataset_test(images_test,masks_test)
address = test_comp['damage label file name'].apply(lambda x : os.path.split(x)[1]).to_numpy()

# %%
#Printing predictions on the component damage test dataset
z=1
for x, y in dataset_test.take(10):
        z += 1
        show_img(x[0])
        show_label(y[0])
        pred = model.predict(x)
        show_pred(pred[0])
        if (z==9):
          break
# Out:
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-48-6e434b7607cb> in <module>()
#       1 #Printing predictions on the component damage test dataset
#       2 z=1
# ----> 3 for x, y in dataset_test.take(10):
#       4         z += 1
#       5         show_img(x[0])
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __next__(self)
#     834   def __next__(self):
#     835     try:
# --> 836       return self._next_internal()
#     837     except errors.OutOfRangeError:
#     838       raise StopIteration
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _next_internal(self)
#     820           self._iterator_resource,
#     821           output_types=self._flat_output_types,
# --> 822           output_shapes=self._flat_output_shapes)
#     823
#     824       try:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    2921       return _result
#    2922     except _core._NotOkStatusException as e:
# -> 2923       _ops.raise_from_not_ok_status(e, name)
#    2924     except _core._FallbackException:
#    2925       pass
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    7184 def raise_from_not_ok_status(e, name):
#    7185   e.message += (" name: " + name if name is not None else "")
# -> 7186   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    7187
#    7188
#
# UnknownError: NotFoundError: /content/drive/MyDrive/Tokaido Dataset/synthetic/test/labdmg/image_case175_frame6.png; No such file or directory [Op:ReadFile]
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/script_ops.py", line 271, in __call__
#     ret = func(*args)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py", line 642, in wrapper
#     return func(*args, **kwargs)
#
#   File "/tmp/__autograph_generated_file6_6iucjl.py", line 17, in f
#     y = ag__.converted_call(ag__.ld(tf).io.read_file, (ag__.ld(y),), None, fscope_1)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py", line 335, in converted_call
#     return _call_unconverted(f, args, kwargs, options, False)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py", line 459, in _call_unconverted
#     return f(*args)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/io_ops.py", line 133, in read_file
#     return gen_io_ops.read_file(filename, name)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_io_ops.py", line 567, in read_file
#     filename, name=name, ctx=_ctx)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_io_ops.py", line 590, in read_file_eager_fallback
#     attrs=_attrs, ctx=ctx, name=name)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py", line 55, in quick_execute
#     inputs, attrs, num_outputs)
#
# tensorflow.python.framework.errors_impl.NotFoundError: /content/drive/MyDrive/Tokaido Dataset/synthetic/test/labdmg/image_case175_frame6.png; No such file or directory [Op:ReadFile]
#
#
# 	 [[{{node PyFunc}}]] [Op:IteratorGetNext]
